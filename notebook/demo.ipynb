# %%
import pandas as pd

# %%
data = pd.read_json('complaints-2023-05-30_06_37.json')

# %%
data.head()
# Out:
#                 _index _type      _id  _score  \
# 0  complaint-public-v1  _doc  6801233     NaN
# 1  complaint-public-v1  _doc  6919272     NaN
# 2  complaint-public-v1  _doc  6919384     NaN
# 3  complaint-public-v1  _doc  6772261     NaN
# 4  complaint-public-v1  _doc  6771703     NaN
#
#                                              _source sort
# 0  {'product': 'Credit reporting, credit repair s...  [0]
# 1  {'product': 'Credit reporting, credit repair s...  [1]
# 2  {'product': 'Credit reporting, credit repair s...  [1]
# 3  {'product': 'Credit reporting, credit repair s...  [4]
# 4  {'product': 'Credit reporting, credit repair s...  [5]

# %%
data['_source'].keys()
# Out:
# RangeIndex(start=0, stop=216190, step=1)

# %%
import json
dataa = 'complaints-2023-05-30_06_37.json'

# %%
data = 'complaints-2023-05-30_06_37.json'

finance_complaint_data = list(map(lambda x: x["_source"],
                                  filter(lambda x: "_source" in x.keys(),
                                         json.loads(data)))
                              )
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[22], line 5
#       1 data = 'complaints-2023-05-30_06_37.json'
#       3 finance_complaint_data = list(map(lambda x: x["_source"],
#       4                                   filter(lambda x: "_source" in x.keys(),
# ----> 5                                          json.loads(data)))
#       6                               )
#
# File ~/Finance-Complaint/venv/lib/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352     del kw['encoding']
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#     359     cls = JSONDecoder
# ...

# %%
source_key
# Out:
# [0         {'product': 'Credit reporting, credit repair s...
#  1         {'product': 'Credit reporting, credit repair s...
#  2         {'product': 'Credit reporting, credit repair s...
#  3         {'product': 'Credit reporting, credit repair s...
#  4         {'product': 'Credit reporting, credit repair s...
#                                  ...
#  216185    {'product': 'Mortgage', 'complaint_what_happen...
#  216186    {'product': 'Money transfer, virtual currency,...
#  216187    {'product': 'Debt collection', 'complaint_what...
#  216188    {'product': 'Debt collection', 'complaint_what...
#  216189    {'product': 'Debt collection', 'complaint_what...
#  Name: _source, Length: 216190, dtype: object,
#  0         {'product': 'Credit reporting, credit repair s...
#  1         {'product': 'Credit reporting, credit repair s...
#  2         {'product': 'Credit reporting, credit repair s...
#  3         {'product': 'Credit reporting, credit repair s...
# ...

# %%
import re

# Example string
text = "Hello, I have 3 apples and 2 oranges."

# Extract all numbers from the string
numbers = re.findall(r'\d+', text)

print(numbers)  # Output: ['3', '2']
# Out:
# ['3', '2']

# %%
list(map(int, numbers))
# Out:
# [3, 2]

# %%
import pandas as pd

# %%
dataframe = pd.read_json('/home/suyodhan/Finance-Complaint/finance_artifact/data_ingestion/20230603_104956/downloaded_files/meta_info.yaml_2023-04-30_2023-05-31.json')

# %%
dataframe.head()
# Out:
#                                              product complaint_what_happened  \
# 0  Credit reporting, credit repair services, or o...
# 1  Credit reporting, credit repair services, or o...
# 2  Credit reporting, credit repair services, or o...
# 3  Credit reporting, credit repair services, or o...
# 4  Credit reporting, credit repair services, or o...
#
#         date_sent_to_company  \
# 0  2023-05-03T12:00:00-05:00
# 1  2023-05-03T12:00:00-05:00
# 2  2023-05-03T12:00:00-05:00
# 3  2023-05-03T12:00:00-05:00
# 4  2023-05-02T12:00:00-05:00
#
#                                                issue       sub_product  \
# 0               Incorrect information on your report  Credit reporting
# 1               Incorrect information on your report  Credit reporting
# 2  Problem with a credit reporting company's inve...  Credit reporting
# 3               Incorrect information on your report  Credit reporting
# 4               Incorrect information on your report  Credit reporting
#
# ...

# %%
dataframe['consumer_disputed'].unique()
# Out:
# array(['N/A'], dtype=object)

# %%
dataframe.head(0)
# Out:
# Empty DataFrame
# Columns: [product, complaint_what_happened, date_sent_to_company, issue, sub_product, zip_code, tags, complaint_id, timely, consumer_consent_provided, company_response, submitted_via, company, date_received, state, consumer_disputed, company_public_response, sub_issue]
# Index: []

# %%
dataframe[['complaint_id']['sub_product']]
# Out:
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# /tmp/ipykernel_26824/1006688114.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   dataframe[['complaint_id']['sub_product']]
# /tmp/ipykernel_26824/1006688114.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   dataframe[['complaint_id']['sub_product']]
# /tmp/ipykernel_26824/1006688114.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   dataframe[['complaint_id']['sub_product']]
# /tmp/ipykernel_26824/1006688114.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   dataframe[['complaint_id']['sub_product']]
# ---------------------------------------------------------------------------
# ...

# %%
unwanted_columns =  dataframe['complaint_id', 'sub_product', 'complaint_what_happened']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Finance-Complaint/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File ~/Finance-Complaint/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Finance-Complaint/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('complaint_id', 'sub_product', 'complaint_what_happened')
#
# ...

# %%
dataframe = dataframe.drop(unwanted_columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 dataframe = dataframe.drop(unwanted_columns)
#
# File ~/Finance-Complaint/venv/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/Finance-Complaint/venv/lib/python3.8/site-packages/pandas/core/frame.py:4906, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4774 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4775 def drop(
#    4776     self,
#    (...)
# ...

# %%
if dataframe.complaint_what_happened == " ":
    print("Hello")
else:
    print("No")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_26824/3256262561.py in ?()
# ----> 1 if dataframe.complaint_what_happened == " ":
#       2     print("Hello")
#       3 else:
#       4     print("No")
#
# ~/Finance-Complaint/venv/lib/python3.8/site-packages/pandas/core/generic.py in ?(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
dataframe.count()
# Out:
# product                      96384
# complaint_what_happened      96384
# date_sent_to_company         96384
# issue                        96384
# sub_product                  96384
# zip_code                     96371
# tags                          6108
# complaint_id                 96384
# timely                       96384
# consumer_consent_provided    17185
# company_response             96384
# submitted_via                96384
# company                      96384
# date_received                96384
# state                        96165
# consumer_disputed            96384
# company_public_response       7291
# sub_issue                    93529
# dtype: int64

# %%
 def unwanted_columns(self) -> List[str]:
        features = [
            self.col_complaint_id,
            self.col_sub_product,
            self.col_complaint_what_happened]

# %%
dataframe['sub_product'].unique()
# Out:
# array(['Credit reporting', 'Checking account', 'Other debt',
#        'Personal line of credit', 'Conventional home mortgage',
#        'General-purpose prepaid card', 'FHA mortgage',
#        'General-purpose credit card or charge card', 'Store credit card',
#        'Medical debt', 'Private student loan', 'I do not know', 'Loan',
#        'Payroll card', 'Other banking product or service',
#        'Mobile or digital wallet', 'Credit card debt',
#        'International money transfer', 'Federal student loan servicing',
#        'Other personal consumer report', 'Credit repair services',
#        'Mortgage debt', 'Title loan', 'Installment loan', 'Auto debt',
#        'Other type of mortgage', 'CD (Certificate of Deposit)',
#        'Savings account', 'Lease', 'Virtual currency',
#        'Foreign currency exchange', 'Payday loan debt', 'Payday loan',
#        'Domestic (US) money transfer',
#        'Home equity loan or line of credit (HELOC)', 'VA mortgage',
# ...

# %%
dataframe.isna().sum()
# Out:
# product                          0
# complaint_what_happened          0
# date_sent_to_company             0
# issue                            0
# sub_product                      0
# zip_code                        13
# tags                         90276
# complaint_id                     0
# timely                           0
# consumer_consent_provided    79199
# company_response                 0
# submitted_via                    0
# company                          0
# date_received                    0
# state                          219
# consumer_disputed                0
# company_public_response      89093
# sub_issue                     2855
# dtype: int64

# %%
dataframe.columns
# Out:
# Index(['product', 'complaint_what_happened', 'date_sent_to_company', 'issue',
#        'sub_product', 'zip_code', 'tags', 'complaint_id', 'timely',
#        'consumer_consent_provided', 'company_response', 'submitted_via',
#        'company', 'date_received', 'state', 'consumer_disputed',
#        'company_public_response', 'sub_issue'],
#       dtype='object')

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96384 entries, 0 to 96383
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   product                    96384 non-null  object
#  1   complaint_what_happened    96384 non-null  object
#  2   date_sent_to_company       96384 non-null  object
#  3   issue                      96384 non-null  object
#  4   sub_product                96384 non-null  object
#  5   zip_code                   96371 non-null  object
#  6   tags                       6108 non-null   object
#  7   complaint_id               96384 non-null  int64
#  8   timely                     96384 non-null  object
#  9   consumer_consent_provided  17185 non-null  object
#  10  company_response           96384 non-null  object
#  11  submitted_via              96384 non-null  object
#  12  company                    96384 non-null  object
# ...

# %%
dataframe.describe()
# Out:
#        complaint_id
# count  9.638400e+04
# mean   6.975066e+06
# std    3.991158e+04
# min    6.907221e+06
# 25%    6.940956e+06
# 50%    6.973514e+06
# 75%    7.006926e+06
# max    7.054757e+06

# %%
dataframe.count()
# Out:
# product                      96384
# complaint_what_happened      96384
# date_sent_to_company         96384
# issue                        96384
# sub_product                  96384
# zip_code                     96371
# tags                          6108
# complaint_id                 96384
# timely                       96384
# consumer_consent_provided    17185
# company_response             96384
# submitted_via                96384
# company                      96384
# date_received                96384
# state                        96165
# consumer_disputed            96384
# company_public_response       7291
# sub_issue                    93529
# dtype: int64

# %%
from finance_complaint.config.spark_manager import spark_session
# Out:
# 23/06/10 16:12:54 WARN Utils: Your hostname, Dell resolves to a loopback address: 127.0.1.1; using 192.168.29.77 instead (on interface wlp0s20f3)
# 23/06/10 16:12:54 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/usr/local/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/suyodhan/.ivy2/cache
# The jars for the packages stored in: /home/suyodhan/.ivy2/jars
# com.amazonaws#aws-java-sdk added as a dependency
# org.apache.hadoop#hadoop-aws added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-3cbeb8b7-ec3d-46a7-93ee-8cbb6a87c180;1.0
# 	confs: [default]
# 	found com.amazonaws#aws-java-sdk;1.7.4 in central
# 	found commons-logging#commons-logging;1.1.1 in central
# 	found org.apache.httpcomponents#httpclient;4.2 in central
# 	found org.apache.httpcomponents#httpcore;4.2 in central
# 	found commons-codec#commons-codec;1.3 in central
# ...

# %%
data = spark_session.read.parquet("/home/suyodhan/Finance-Complaint/finance_artifact/data_ingestion/feature_store/meta_info.yaml/").limit(1000)

# %%
len(data.columns)
# Out:
# 18

# %%
data.show(10)
# Out:
# +--------------------+-----------------------+--------------------+------------+-----------------------+-------------------------+-----------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+----------------+-------------+----+------+--------+
# |             company|company_public_response|    company_response|complaint_id|complaint_what_happened|consumer_consent_provided|consumer_disputed|       date_received|date_sent_to_company|               issue|             product|state|           sub_issue|     sub_product|submitted_via|tags|timely|zip_code|
# +--------------------+-----------------------+--------------------+------------+-----------------------+-------------------------+-----------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+----------------+-------------+----+------+--------+
# ...

# %%
columns= list(filter((lambda x:x in self.schema.required_columns), dataframe.columns))

# %%
dataframe.head(2)
# Out:
#                                              product complaint_what_happened  \
# 0  Credit reporting, credit repair services, or o...
# 1  Credit reporting, credit repair services, or o...
#
#         date_sent_to_company                                 issue  \
# 0  2023-05-03T12:00:00-05:00  Incorrect information on your report
# 1  2023-05-03T12:00:00-05:00  Incorrect information on your report
#
#         sub_product zip_code  tags  complaint_id timely  \
# 0  Credit reporting    19140  None       6919272    Yes
# 1  Credit reporting    30144  None       6919146    Yes
#
#   consumer_consent_provided company_response submitted_via        company  \
# 0                      None      In progress           Web  EQUIFAX, INC.
# 1                      None      In progress           Web  EQUIFAX, INC.
#
#                date_received state consumer_disputed company_public_response  \
# 0  2023-05-03T12:00:00-05:00    PA               N/A                    None
# ...

# %%
dataframe.columns
# Out:
# Index(['product', 'complaint_what_happened', 'date_sent_to_company', 'issue',
#        'sub_product', 'zip_code', 'tags', 'complaint_id', 'timely',
#        'consumer_consent_provided', 'company_response', 'submitted_via',
#        'company', 'date_received', 'state', 'consumer_disputed',
#        'company_public_response', 'sub_issue'],
#       dtype='object')

# %%
from pyspark.sql.functions import col

for column in data.columns:
    n_unique = data.select(col(column)).distinct().count()
    n_missing = data.filter(col(column).isNull()).count()
    missing_percentage = (n_missing * 100) / dataframe.count()

    print(f"n_unique : {n_unique}")
    print(f"n_missing : {n_missing}")
    print(f"missing_percentage : {missing_percentage}")
# Out:
# n_unique : 133
# n_missing : 0
# missing_percentage : product                      0.0
# complaint_what_happened      0.0
# date_sent_to_company         0.0
# issue                        0.0
# sub_product                  0.0
# zip_code                     0.0
# tags                         0.0
# complaint_id                 0.0
# timely                       0.0
# consumer_consent_provided    0.0
# company_response             0.0
# submitted_via                0.0
# company                      0.0
# date_received                0.0
# state                        0.0
# consumer_disputed            0.0
# company_public_response      0.0
# sub_issue                    0.0
# dtype: float64
# n_unique : 7
# n_missing : 662
# missing_percentage : product                       0.686836
# complaint_what_happened       0.686836
# date_sent_to_company          0.686836
# issue                         0.686836
# sub_product                   0.686836
# ...

# %%
from pyspark.sql.functions import col
for column in data.columns:
    print(data.filter(col(column).isNull()).count())
# Out:
# 0
# 662
# 0
# 0
# 0
# 550
# 0
# 0
# 0
# 0
# 0
# 1
# 46
# 0
# 0
# 929
# 0
# 0

# %%
for column in dataframe.columns:
    # n_unique: int = dataframe.select(col(column)).distinct().count()
    n_missing: int = dataframe.filter(col(column).isNull()).count()
    missing_percentage: float = (n_missing * 100) / dataframe.count()

    # print(n_unique)
    print(n_missing)
    print(missing_percentage)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 for column in dataframe.columns:
#       2     # n_unique: int = dataframe.select(col(column)).distinct().count()
# ----> 3     n_missing: int = dataframe.filter(col(column).isNull()).count()
#       4     missing_percentage: float = (n_missing * 100) / dataframe.count()
#       6     # print(n_unique)
#
# File ~/Finance-Complaint/venv/lib/python3.8/site-packages/pandas/core/generic.py:4982, in NDFrame.filter(self, items, like, regex, axis)
#    4980 if items is not None:
#    4981     name = self._get_axis_name(axis)
# -> 4982     return self.reindex(**{name: [r for r in items if r in labels]})
#    4983 elif like:
#    4985     def f(x) -> bool_t:
#
# File ~/Finance-Complaint/venv/lib/python3.8/site-packages/pyspark/sql/column.py:463, in Column.__iter__(self)
#     462 def __iter__(self):
# ...

# %%
l = ['consumer_disputed', 'company_response', 'consumer_consent_provided', 'submitted_via', 'issue', 'date_sent_to_company', 'date_received']

# %%
l
# Out:
# ['consumer_disputed',
#  'company_response',
#  'consumer_consent_provided',
#  'submitted_via',
#  'issue',
#  'date_sent_to_company',
#  'date_received']

# %%
columns = list(filter(lambda x: x in l,
                                data.columns))

# %%
columns
# Out:
# ['company_response',
#  'consumer_consent_provided',
#  'consumer_disputed',
#  'date_received',
#  'date_sent_to_company',
#  'issue',
#  'submitted_via']

# %%
 def one_hot_encoding_features(self) -> List[str]:
        features = [
            self.col_company_response,
            self.col_consumer_consent_provided,
            self.col_submitted_via,
        ]

# %%
data.filter(data.consumer_disputed.isNull()).collect()
# Out:
# []

# %%
data.columns
# Out:
# ['company',
#  'company_public_response',
#  'company_response',
#  'complaint_id',
#  'complaint_what_happened',
#  'consumer_consent_provided',
#  'consumer_disputed',
#  'date_received',
#  'date_sent_to_company',
#  'issue',
#  'product',
#  'state',
#  'sub_issue',
#  'sub_product',
#  'submitted_via',
#  'tags',
#  'timely',
#  'zip_code']

# %%
unwanted_columns = ['complaint_id', 'sub_product', 'complaint_what_happened']

# %%
data[unwanted_columns]
# Out:
# DataFrame[complaint_id: string, sub_product: string, complaint_what_happened: string]

# %%
len(data.columns)
# Out:
# 18

# %%
new_data = data.select(unwanted_columns)

# %%
new_data.head(10)
# Out:
# [Row(complaint_id='6902749', sub_product='Credit reporting', complaint_what_happened=''),
#  Row(complaint_id='6906711', sub_product='Credit reporting', complaint_what_happened=''),
#  Row(complaint_id='6881697', sub_product='Credit reporting', complaint_what_happened=''),
#  Row(complaint_id='6902341', sub_product='Credit reporting', complaint_what_happened=''),
#  Row(complaint_id='6902174', sub_product='Credit reporting', complaint_what_happened=''),
#  Row(complaint_id='6902175', sub_product='Credit reporting', complaint_what_happened=''),
#  Row(complaint_id='6902176', sub_product='Credit reporting', complaint_what_happened=''),
#  Row(complaint_id='6902409', sub_product='Credit reporting', complaint_what_happened=''),
#  Row(complaint_id='6902433', sub_product='Credit reporting', complaint_what_happened=''),
#  Row(complaint_id='6902272', sub_product='Credit reporting', complaint_what_happened='')]

# %%
new_data = data.drop(*unwanted_columns)

# %%
new_data
# Out:
# DataFrame[company: string, company_public_response: string, company_response: string, consumer_consent_provided: string, consumer_disputed: string, date_received: string, date_sent_to_company: string, issue: string, product: string, state: string, sub_issue: string, submitted_via: string, tags: string, timely: string, zip_code: string]

# %%
len(new_data.columns)
# Out:
# 15

# %%
len(data.columns)
# Out:
# 18

# %%
collect = data.collect()

# %%
for row in data.collect():
    for column in data.columns:
        print(column, row[column])
    print()
# Out:
# company Experian Information Solutions Inc.
# company_public_response None
# company_response In progress
# complaint_id 6902749
# complaint_what_happened
# consumer_consent_provided None
# consumer_disputed N/A
# date_received 2023-04-28T12:00:00-05:00
# date_sent_to_company 2023-04-28T12:00:00-05:00
# issue Problem with a credit reporting company's investigation into an existing problem
# product Credit reporting, credit repair services, or other personal consumer reports
# state CA
# sub_issue Their investigation did not fix an error on your report
# sub_product Credit reporting
# submitted_via Web
# tags None
# timely Yes
# zip_code 92883
#
# company NAVY FEDERAL CREDIT UNION
# company_public_response None
# company_response In progress
# complaint_id 6906711
# complaint_what_happened
# consumer_consent_provided None
# consumer_disputed N/A
# date_received 2023-04-29T12:00:00-05:00
# date_sent_to_company 2023-04-29T12:00:00-05:00
# issue Incorrect information on your report
# ...

# %%
l = ]StructField("company", StringType(), nullable=True),
            StructField("company_public_response", StringType(), nullable=True),
            StructField("company_response", StringType(), nullable=True),
            StructField("complaint_id", StringType(), nullable=True),
            StructField("complaint_what_happened", StringType(), nullable=True),
            StructField("consumer_consent_provided", StringType(), nullable=True),
            StructField("consumer_disputed", StringType(), nullable=True),
            StructField("date_received", StringType(), nullable=True),
            StructField("date_sent_to_company", StringType(), nullable=True),
            StructField("issue", StringType(), nullable=True),
            StructField("product", StringType(), nullable=True),
            StructField("state", StringType(), nullable=True),
            StructField("sub_issue", StringType(), nullable=True),
            StructField("sub_product", StringType(), nullable=True),
            StructField("submitted_via", StringType(), nullable=True),
            StructField("tags", StringType(), nullable=True),
            StructField("timely", StringType(), nullable=True),
            StructField("zip_code", StringType(), nullable=True)

# %%
data.columns
# Out:
# ['company',
#  'company_public_response',
#  'company_response',
#  'complaint_id',
#  'complaint_what_happened',
#  'consumer_consent_provided',
#  'consumer_disputed',
#  'date_received',
#  'date_sent_to_company',
#  'issue',
#  'product',
#  'state',
#  'sub_issue',
#  'sub_product',
#  'submitted_via',
#  'tags',
#  'timely',
#  'zip_code']

# %%
data.head()
# Out:
# Row(company='Experian Information Solutions Inc.', company_public_response=None, company_response='In progress', complaint_id='6902749', complaint_what_happened='', consumer_consent_provided=None, consumer_disputed='N/A', date_received='2023-04-28T12:00:00-05:00', date_sent_to_company='2023-04-28T12:00:00-05:00', issue="Problem with a credit reporting company's investigation into an existing problem", product='Credit reporting, credit repair services, or other personal consumer reports', state='CA', sub_issue='Their investigation did not fix an error on your report', sub_product='Credit reporting', submitted_via='Web', tags=None, timely='Yes', zip_code='92883')

# %%
demo

# %%
os.getenv('AWS_ACCESS_KEY_ID')
# Out:
# 'AKIA6EOXBVIUU4TOWIFF'

# %%
from pyspark.sql import SparkSession

# %%
from finance_complaint.constant.environment.variable_key import AWS_ACCESS_KEY_ID_ENV_KEY,AWS_SECRET_ACCESS_KEY_ENV_KEY
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from finance_complaint.constant.environment.variable_key import AWS_ACCESS_KEY_ID_ENV_KEY,AWS_SECRET_ACCESS_KEY_ENV_KEY
#
# ModuleNotFoundError: No module named 'finance_complaint.constant.environment'

# %%
from finance_complaint.config.spark_manager import spark_session
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from finance_complaint.config.spark_manager import spark_session
#
# ModuleNotFoundError: No module named 'finance_complaint.config.spark_manager'

# %%
df = spark_session.read.json(json_file_path)
